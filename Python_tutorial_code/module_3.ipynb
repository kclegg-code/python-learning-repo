# %%
import pandas as pd
#read from local files example
import os
#sen_filename = r"address"

# %%
filename = r"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/1980%202023%20average%20house%20prices.csv"

# Datafrane - shorthand df

house_prices = pd.read_csv(filename)

# for an excel file - excel_file = pd.read_excel(filename, sheet_name=['sheet 1',sheet 3'])
#instead of returning 1 dataframe, it will return a dictionary {} where the keys are the sheet names and the values are the dataframes
# if bringing in an exel file we need to import openpyxl (standard in Anaconda)

#don't need to add 'print' in pandas to display outcome

house_prices
# Out:
#                Name   Period  House price index All property types  \
# 0    United Kingdom  1980-01                                 10.11
# 1    United Kingdom  1980-02                                 10.11
# 2    United Kingdom  1980-03                                 10.11
# 3    United Kingdom  1980-04                                 10.51
# 4    United Kingdom  1980-05                                 10.51
# ..              ...      ...                                   ...
# 518  United Kingdom  2023-03                                148.20
# 519  United Kingdom  2023-04                                148.90
# 520  United Kingdom  2023-05                                149.50
# 521  United Kingdom  2023-06                                151.20
# 522  United Kingdom  2023-07                                152.00
#
#      Average price All property types  \
# 0                               19273
# 1                               19273
# 2                               19273
# ...

# %%
house_prices.info()
house_prices.head()
house_proices.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523 entries, 0 to 522
# Data columns (total 6 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Name                                            523 non-null    object
#  1   Period                                          523 non-null    object
#  2   House price index All property types            523 non-null    float64
#  3   Average price All property types                523 non-null    int64
#  4   Percentage change (monthly) All property types  523 non-null    float64
#  5   Percentage change (yearly) All property types   523 non-null    float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 24.6+ KB
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 3
# ...

# %%
child_id_file= r"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/ChildIdentifiers.csv"

child_id = pd.read_csv(child_id_file)

child_id
# Out:
#      Unnamed: 0        LAchildID            UPN  FormerUPN  UPNunknown  \
# 0             0  RND000215205141  A850728973744        NaN         NaN
# 1             1  RND000824303014  A141396438491        NaN         NaN
# 2             2  RND000750143123  A929946861554        NaN         NaN
# 3             3  RND000909164501  A612330267292        NaN         NaN
# 4             4  RND000382171815  A604459366806        NaN         NaN
# ..          ...              ...            ...        ...         ...
# 327         327  RND000112711501  A465246916125        NaN         NaN
# 328         328  RND000513120794  A540014111973        NaN         NaN
# 329         329  RND000541643134  A549582689058        NaN         NaN
# 330         330  RND000404939452  A889492349196        NaN         NaN
# 331         331  RND000589802835  A877624860226        NaN         NaN
#
#     PersonBirthDate ExpectedPersonBirthDate  GenderCurrent PersonDeathDate
# ...

# %%
child_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               332 non-null    int64
#  1   LAchildID                332 non-null    object
#  2   UPN                      332 non-null    object
#  3   FormerUPN                0 non-null      float64
#  4   UPNunknown               0 non-null      float64
#  5   PersonBirthDate          332 non-null    object
#  6   ExpectedPersonBirthDate  7 non-null      object
#  7   GenderCurrent            332 non-null    int64
#  8   PersonDeathDate          21 non-null     object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 23.5+ KB

# %%
child_id.head()
# Out:
#    Unnamed: 0        LAchildID            UPN  FormerUPN  UPNunknown  \
# 0           0  RND000215205141  A850728973744        NaN         NaN
# 1           1  RND000824303014  A141396438491        NaN         NaN
# 2           2  RND000750143123  A929946861554        NaN         NaN
# 3           3  RND000909164501  A612330267292        NaN         NaN
# 4           4  RND000382171815  A604459366806        NaN         NaN
#
#   PersonBirthDate ExpectedPersonBirthDate  GenderCurrent PersonDeathDate
# 0      2019-12-06                     NaN              1             NaN
# 1      2011-04-27                     NaN              9             NaN
# 2      2017-06-06              2019-12-06              1             NaN
# 3      2014-10-03                     NaN              0             NaN
# 4      2019-09-25                     NaN              2             NaN

# %%
child_id.tail()
# Out:
#      Unnamed: 0        LAchildID            UPN  FormerUPN  UPNunknown  \
# 327         327  RND000112711501  A465246916125        NaN         NaN
# 328         328  RND000513120794  A540014111973        NaN         NaN
# 329         329  RND000541643134  A549582689058        NaN         NaN
# 330         330  RND000404939452  A889492349196        NaN         NaN
# 331         331  RND000589802835  A877624860226        NaN         NaN
#
#     PersonBirthDate ExpectedPersonBirthDate  GenderCurrent PersonDeathDate
# 327      2010-07-07                     NaN              2             NaN
# 328      2018-08-14                     NaN              2             NaN
# 329      2021-12-09                     NaN             51             NaN
# 330      2013-07-23                     NaN              2             NaN
# 331      2021-10-25                     NaN              9             NaN

# %%
child_id['PersonBirthDate']
# Out:
# 0      2019-12-06
# 1      2011-04-27
# 2      2017-06-06
# 3      2014-10-03
# 4      2019-09-25
#           ...
# 327    2010-07-07
# 328    2018-08-14
# 329    2021-12-09
# 330    2013-07-23
# 331    2021-10-25
# Name: PersonBirthDate, Length: 332, dtype: object

# %%
child_id['PersonBirthDate'] = pd.to_datetime(child_id['PersonBirthDate'], format="%Y-%m-%d", errors="ignore")
         
child_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               332 non-null    int64
#  1   LAchildID                332 non-null    object
#  2   UPN                      332 non-null    object
#  3   FormerUPN                0 non-null      float64
#  4   UPNunknown               0 non-null      float64
#  5   PersonBirthDate          332 non-null    datetime64[ns]
#  6   ExpectedPersonBirthDate  7 non-null      object
#  7   GenderCurrent            332 non-null    int64
#  8   PersonDeathDate          21 non-null     object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 23.5+ KB
# ...

# %%
child_id['PersonDeathDate'] = pd.to_datetime(child_id['PersonDeathDate'], format="%Y-%m-%d", errors="coerce")
         
child_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               332 non-null    int64
#  1   LAchildID                332 non-null    object
#  2   UPN                      332 non-null    object
#  3   FormerUPN                0 non-null      float64
#  4   UPNunknown               0 non-null      float64
#  5   PersonBirthDate          332 non-null    datetime64[ns]
#  6   ExpectedPersonBirthDate  7 non-null      object
#  7   GenderCurrent            332 non-null    int64
#  8   PersonDeathDate          20 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(2), object(3)
# memory usage: 23.5+ KB

# %%
house_prices['Period'] = pd.to_datetime(house_prices['Period'], format="%Y-%m")

house_prices

house_prices['Age of data'] = pd.to_datetime('today') - house_prices ['Period']

house_prices['Age of data'] = house_prices['Age of data'] / pd.Timedelta(365.25, 'd')

house_prices['Age of data'] = house_prices['Age of data'].astype('int')
house_prices

# instead of today do'01/04/2024'
# Out:
#                Name     Period  House price index All property types  \
# 0    United Kingdom 1980-01-01                                 10.11
# 1    United Kingdom 1980-02-01                                 10.11
# 2    United Kingdom 1980-03-01                                 10.11
# 3    United Kingdom 1980-04-01                                 10.51
# 4    United Kingdom 1980-05-01                                 10.51
# ..              ...        ...                                   ...
# 518  United Kingdom 2023-03-01                                148.20
# 519  United Kingdom 2023-04-01                                148.90
# 520  United Kingdom 2023-05-01                                149.50
# 521  United Kingdom 2023-06-01                                151.20
# 522  United Kingdom 2023-07-01                                152.00
#
#      Average price All property types  \
# 0                               19273
# 1                               19273
# ...

# %%
child_id
# Out:
#      Unnamed: 0        LAchildID            UPN  FormerUPN  UPNunknown  \
# 0             0  RND000215205141  A850728973744        NaN         NaN
# 1             1  RND000824303014  A141396438491        NaN         NaN
# 2             2  RND000750143123  A929946861554        NaN         NaN
# 3             3  RND000909164501  A612330267292        NaN         NaN
# 4             4  RND000382171815  A604459366806        NaN         NaN
# ..          ...              ...            ...        ...         ...
# 327         327  RND000112711501  A465246916125        NaN         NaN
# 328         328  RND000513120794  A540014111973        NaN         NaN
# 329         329  RND000541643134  A549582689058        NaN         NaN
# 330         330  RND000404939452  A889492349196        NaN         NaN
# 331         331  RND000589802835  A877624860226        NaN         NaN
#
#     PersonBirthDate ExpectedPersonBirthDate  GenderCurrent PersonDeathDate
# ...

# %%
child_id['Age'] = pd.to_datetime('01/04/2024', dayfirst=True) - child_id ['PersonBirthDate']

child_id['Age'] = child_id['Age'] / pd.Timedelta(365.25, 'd')

child_id['Age'] = child_id['Age'].astype('int')
child_id
# Out:
#      Unnamed: 0        LAchildID            UPN  FormerUPN  UPNunknown  \
# 0             0  RND000215205141  A850728973744        NaN         NaN
# 1             1  RND000824303014  A141396438491        NaN         NaN
# 2             2  RND000750143123  A929946861554        NaN         NaN
# 3             3  RND000909164501  A612330267292        NaN         NaN
# 4             4  RND000382171815  A604459366806        NaN         NaN
# ..          ...              ...            ...        ...         ...
# 327         327  RND000112711501  A465246916125        NaN         NaN
# 328         328  RND000513120794  A540014111973        NaN         NaN
# 329         329  RND000541643134  A549582689058        NaN         NaN
# 330         330  RND000404939452  A889492349196        NaN         NaN
# 331         331  RND000589802835  A877624860226        NaN         NaN
#
#     PersonBirthDate ExpectedPersonBirthDate  GenderCurrent PersonDeathDate  \
# ...

# %%
#child_info = pd.merge(child_info, nhs_numbers, how='left', left_on='ChildId', right_on='ChildId')
#child_info
